# %%
import pandas as pd

# %%
PRESIDENT_DATA_PATH = ('1976-2020-president.csv')
data_president_df = pd.read_csv(PRESIDENT_DATA_PATH)
data_president_df
# Out:
#       year    state state_po  state_fips  state_cen  state_ic        office  \
# 0     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 1     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 2     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 3     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 4     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# ...    ...      ...      ...         ...        ...       ...           ...
# 4282  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4283  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4284  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4285  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4286  2020  WYOMING       WY          56         83        68  US PRESIDENT
#
# ...

# %%
data_president_year_2020_df = data_president_df[data_president_df['year'] == 2020]
data_president_year_2020_df
# Out:
#       year    state state_po  state_fips  state_cen  state_ic        office  \
# 3740  2020  ALABAMA       AL           1         63        41  US PRESIDENT
# 3741  2020  ALABAMA       AL           1         63        41  US PRESIDENT
# 3742  2020  ALABAMA       AL           1         63        41  US PRESIDENT
# 3743  2020  ALABAMA       AL           1         63        41  US PRESIDENT
# 3744  2020   ALASKA       AK           2         94        81  US PRESIDENT
# ...    ...      ...      ...         ...        ...       ...           ...
# 4282  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4283  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4284  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4285  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4286  2020  WYOMING       WY          56         83        68  US PRESIDENT
#
# ...

# %%
columns_relevant = ['year', 'state', 'candidate', 'candidatevotes', 'party_simplified']
data_president_columns_filtered_df = data_president_year_2020_df[columns_relevant]
data_president_columns_filtered_df
# Out:
#       year    state            candidate  candidatevotes party_simplified
# 3740  2020  ALABAMA  BIDEN, JOSEPH R. JR          849624         DEMOCRAT
# 3741  2020  ALABAMA     TRUMP, DONALD J.         1441170       REPUBLICAN
# 3742  2020  ALABAMA        JORGENSEN, JO           25176      LIBERTARIAN
# 3743  2020  ALABAMA                  NaN            7312            OTHER
# 3744  2020   ALASKA  BIDEN, JOSEPH R. JR          153778         DEMOCRAT
# ...    ...      ...                  ...             ...              ...
# 4282  2020  WYOMING        JORGENSEN, JO            5768      LIBERTARIAN
# 4283  2020  WYOMING        PIERCE, BROCK            2208            OTHER
# 4284  2020  WYOMING                  NaN            1739            OTHER
# 4285  2020  WYOMING            OVERVOTES             279            OTHER
# 4286  2020  WYOMING           UNDERVOTES            1459            OTHER
#
# [547 rows x 5 columns]

# %%
state_party_sum_of_votes = data_president_columns_filtered_df.groupby(['state', 'party_simplified'])['candidatevotes'].sum().reset_index()

index_party_bigger_vote_by_state = state_party_sum_of_votes.groupby(['state'])['candidatevotes'].transform(max) == state_party_sum_of_votes['candidatevotes']
most_votes_by_party = state_party_sum_of_votes[index_party_bigger_vote_by_state]

# Se houver empates, isso manterá apenas a primeira ocorrência
most_votes_by_party = most_votes_by_party.drop_duplicates(subset=['state'], keep='first')
most_votes_by_party
# Out:
#                     state party_simplified  candidatevotes
# 3                 ALABAMA       REPUBLICAN         1441170
# 7                  ALASKA       REPUBLICAN          189951
# 8                 ARIZONA         DEMOCRAT         1672143
# 15               ARKANSAS       REPUBLICAN          760647
# 16             CALIFORNIA         DEMOCRAT        11110250
# 20               COLORADO         DEMOCRAT         1804352
# 24            CONNECTICUT         DEMOCRAT         1080831
# 28               DELAWARE         DEMOCRAT          296268
# 32   DISTRICT OF COLUMBIA         DEMOCRAT          317323
# 39                FLORIDA       REPUBLICAN         5668731
# 40                GEORGIA         DEMOCRAT         2473633
# 44                 HAWAII         DEMOCRAT          366130
# 51                  IDAHO       REPUBLICAN          554119
# 52               ILLINOIS         DEMOCRAT         3471915
# 59                INDIANA       REPUBLICAN         1729519
# ...
